# %%
from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt

# Load the YOLO model
model = YOLO("bestest.pt")

# Run inference on the image
results = model("l.jpg")  # Make sure this path is correct

# Get the annotated image with bounding boxes
annotated_img = results[0].plot()

# Convert BGR (OpenCV) to RGB (Matplotlib)
annotated_img_rgb = cv2.cvtColor(annotated_img, cv2.COLOR_BGR2RGB)

# Save the output image
cv2.imwrite("output.jpg", annotated_img)

# Display using Matplotlib
plt.figure(figsize=(10, 8))
plt.imshow(annotated_img_rgb)
plt.axis('off')
plt.title("YOLOv8 Detection")
plt.show()
# Out:
# image 1/1 /home/developer/Desktop/y/l.jpg: 544x640 4 bottles, 52.0ms
# Speed: 0.9ms preprocess, 52.0ms inference, 0.9ms postprocess per image at shape (1, 3, 544, 640)
